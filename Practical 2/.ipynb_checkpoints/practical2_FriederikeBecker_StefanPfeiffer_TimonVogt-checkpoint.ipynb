# %% [markdown]
# # Practical 2

# %%
## Setups
# !conda update pandas -y
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working...
#
# Updating pandas is constricted by
#
# anaconda -> requires pandas==1.0.1=py37h47e9c7a_0
#
# If you are sure you want an update of your package either try `conda update --all` or install a specific version of the package you want using `conda install <pkg>=<version>`
#
# done
#
# # All requested packages already installed.

# %% [markdown]
# # Task 1: The Data
#
# We use the mouse protein expression dataset: https://archive.ics.uci.edu/ml/datasets/Mice+Protein+Expression
#
# Please use the dataset loading code provided below.
#
# **Tasks 1.1: Dataset Exploration**
# - How many samples / features are provided?
# - How many labels does the dataset have?
# - What is the value range of the predictors?
# - Visualize the 10 first samples of the dataset
# - Visualize the variance of each predictor.

# %%
import math
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

import os
print(pd.__version__)
print(os.getcwd())

file = 'data/Data_Cortex_Nuclear.csv'
df = pd.read_csv(file)
print(df.shape)
print("")

N = 10  # use only every tenth sample
X_all = df.iloc[::N,1:65].to_numpy()
t_all = (df['Behavior'] == 'S/C').to_numpy()[::N]

idx = ~np.any(np.isnan(X_all), axis=1)
X_all = X_all[idx]
t_all = t_all[idx]
# Out:
# 1.0.1
# E:\tmp\ml\Practical 2
# (1080, 82)

# %%
# Value range
min = 1000
max = -1000
for x in X_all:
    m_min = 1000
    m_max = -1000
    for y in x:
        if y < m_min:
            m_min = y
        if y > m_max:
            m_max = y
    
    if m_min < min:
        min = m_min
    if m_max > max:
        max = m_max
print("Min: ", min, " Max: ", max)
print(X_all.shape)
# Out:
# Min:  0.06067111099999999  Max:  7.4640702139999995
# (105, 64)

# %%
# Visualization of samples
fig, ax = plt.subplots(2, 5, figsize=(35, 15))
fig.tight_layout(pad=4.0)
for y in range(2):
    for x in range(5):
        el = X_all[y*2 + x]
        ax[y, x].bar(range(len(el)), el)
        ax[y, x].set_title("Sample: " + str(y*2 + x))

# %%
# Visualization of the variance of the predictors
variances = []
for i in range(len(X_all)):
    x = X_all[i]
    v = np.var(x)
    variances.append(v)
plt.bar(range(len(X_all)), variances)
plt.title("Variances of different predictors")
# Out:
# Text(0.5, 1.0, 'Variances of different predictors')

# %% [markdown]
# **Task 1.1 - Answers**:
# - The dataset provides 1080 samples, with 77 features (protein modifications)
#
# - The dataset has 8 different labels: (c-CS-s, c-CS-m, c-SC-s, c-SC-m, t-CS-s, t-CS-m, t-SC-s, t-SC-m)
#
# - The minimum of the values of the predictors is usually around ~0.1 while the maximum of those values differs a lot more and is around ~2-8 depending on the predictor. Therefore the general value range is probably (0-8).
#
#
# **Task 1.2: Data Preprocessing**:
# - Write a function `split_data(X, y, frac, max_samples, seed)` that first shuffles your training data and then splits it into a training and a test set. `frac` determines the relative size of the test dataset, `seed` makes sure we get reproducible
# results.
# - Write a function `preprocess(X, y)` which zero-centers your data and sets variance to one.

# %%
import copy

def split_data(X, y, frac=0.3, max_samples=None, seed=None):
    if seed is not None:
        np.random.seed(seed)

    # Make copies of the dataset
    _X = copy.deepcopy(X)
    _y = copy.deepcopy(y)        
        
    random_state = np.random.get_state()
    np.random.shuffle(_X)
    np.random.set_state(random_state)
    np.random.shuffle(_y)
    
    N = math.floor(len(_X) * frac)
    X_test = _X[:N]
    X_train = _X[N:]
    
    y_test = _y[:N]
    y_train = _y[N:]
    
    return X_train, X_test, y_train, y_test

def preprocess(X, y):
    # Zero centering: setting the mean of each column to zero, means: subtracting the column-mean from each element
    # (assuming each column seperately)
    X = X - X.mean(axis=0)
    #y = y - y.mean(axis=0)
    
    # Set the variance to one, means: dividing each element by the column-standard-deviation
    # (assuming each column seperately)
    X = X / X.std()
    #y = y / y.std()
    
    return X, y

# %% [markdown]
# # Task 2: LDA
#
# First, use Linear Discriminant Analysis to separate the classes. As discussed in the Bishop in pg. 186-189, we can find a weight vector $\vec{w}$ that performs a projection of the i-th input data point $\vec{x}_i$
#
# $p =   \vec{w}^T \vec{x}_i$
#
# that optimally separates the classes.
#
# Use the analytic solution to compute the optimal weights $\vec{w}$ from the training set data.
#
# **Task 2.1**
#
# 1. Implement a function `compute_lda_weights(x, y)`, which carries out LDA using the data `x,y`.
# 2. Apply this function on your training data.
# 3. Visualize the obtained weight vector $\vec{w}$ using a `plt.stemplot`.

# %%
def compute_lda_weights(x, y):
    
    # Preprocessing
    #x, y = preprocess(x, y)
    
    # Split dataset into 2 classes
    c1, c2 = [], []
    for i in range(len(x)):
        if(y[i]):
            c1.append(x[i])
        else:
            c2.append(x[i])
            
    c1 = np.array(c1)
    c2 = np.array(c2)
            
    # Calculate means:   
    tmp = np.zeros((64,))
    for c in c1:
        tmp = tmp + c[:, None]
    tmp = tmp / len(c1)
    
    m1 = np.mean(c1, axis=0)[:, None]
    m2 = np.mean(c2, axis=0)[:, None]
    mdiff = m2 - m1
        
    # Calculate within-class variance and its inverse    
    s_w = np.zeros((1,64))
    for n in c1:
        n = n[:, None]
        s_w = s_w + np.dot((n - m1), (n - m1).T)
        
    for n in c2:
        n = n[:, None]
        s_w = s_w + np.dot((n - m2), (n - m2).T)
        
    inv_s_w = np.linalg.inv(s_w)
    weights = np.dot(inv_s_w, mdiff)
    
    return m1, m2, mdiff, weights

# %%
X, X_test, t, t_test = split_data(X_all, t_all, seed=1)
m0, m1, mdiff, w_lda = compute_lda_weights(X, t)

#w_lda = np.random.uniform(-1, 1, 50)  # example data
plt.stem(w_lda.flatten(), use_line_collection=True)
plt.title('Computed LDA weights')
plt.ylabel('weight')
plt.xlabel('predictors')
# Out:
# Text(0.5, 0, 'predictors')

# %% [markdown]
# **Task 2.3**
#
# Project the training data and the test data on $\vec{w}$. Visualize the class separation using a two-color histogram.
# - Is the class separation good?
# - Is there a big difference between training and test data?

# %%
#a, b = np.random.normal(2, 1, 20), np.random.normal(0, 1, 20)  # example data
fig, ax = plt.subplots(1,2, figsize=(20,8))

# Training data
a, b = [], []
for i in range(len(X)):
    if(t[i]):
        a.append(np.dot(w_lda[:, 0].T, X[i]))
    else:
        b.append(np.dot(w_lda[:, 0].T, X[i]))

a = np.array(a)
b = np.array(b)

ax[0].set_title('Training data projection')
_ = ax[0].hist(a,label='class 0',alpha=0.5)
_ = ax[0].hist(b,label='class 1',alpha=0.5)


# Test data
a, b = [], []
for i in range(len(X_test)):
    if(t_test[i]):
        a.append(np.dot(w_lda[:, 0].T, X_test[i]))
    else:
        b.append(np.dot(w_lda[:, 0].T, X_test[i]))

a = np.array(a)
b = np.array(b)

ax[1].set_title('Test data projection')
_ = ax[1].hist(a,label='class 0',alpha=0.5)
_ = ax[1].hist(b,label='class 1',alpha=0.5)

# %% [markdown]
# **Answers for Task 2.3**
# 1. On the training data, the class seperation is very good, while on the test data the seperation is less good. Still, even on the test data, it is adequat.
# 2. The test data is much less well seperated than the training data. This is a hint for overfitting.

# %% [markdown]
# **Task 2.4**
#
# Now we make class predictions based on the projections. Read https://en.wikipedia.org/wiki/Linear_discriminant_analysis#Fisher's_linear_discriminant and compute threshold $c$ for the projected values $p$ based on the training data. Print the value of $c$ and plot $c$ into the histograms of projected values you made before!
#
# Use $c$ to assign class labels for training and test set. Determine the classification errors on both datasets and print them.

# %%
# Calculating the threshold
def calc_threshold(m0, m1, weights):
    c = np.dot(weights[:, 0], 0.5 * (m0 + m1)[:, 0])
    print(c)
    return c

def plot_histograms_with_c(c, w_lda, X, t, X_test, t_test):
    fig, ax = plt.subplots(1,2, figsize=(20,8))

    # Training data
    a, b = [], []
    for i in range(len(X)):
        if(t[i]):
            a.append(np.dot(w_lda[:, 0], X[i]))
        else:
            b.append(np.dot(w_lda[:, 0], X[i]))

    a = np.array(a)
    b = np.array(b)

    ax[0].set_title('Training data projection')
    _ = ax[0].hist(a,label='class 0',alpha=0.5)
    _ = ax[0].hist(b,label='class 1',alpha=0.5)
    _ = ax[0].plot([c, c], [0, 10], color='r', linestyle='-', linewidth=2)


    # Test data
    a, b = [], []
    for i in range(len(X_test)):
        if(t_test[i]):
            a.append(np.dot(w_lda[:, 0], X_test[i]))
        else:
            b.append(np.dot(w_lda[:, 0], X_test[i]))

    a = np.array(a)
    b = np.array(b)

    ax[1].set_title('Test data projection')
    _ = ax[1].hist(a,label='class 0',alpha=0.5)
    _ = ax[1].hist(b,label='class 1',alpha=0.5)
    _ = ax[1].plot([c, c], [0, 10], color='r', linestyle='-', linewidth=2)
    
    
def assign_labels_by_c(c, w_lda, X, X_test, t, t_test):
    
    errors = 0
    for i in range(len(X)):
        r = np.dot(w_lda[:, 0], X[i])
        label = r < c
        if label != t[i]:
            errors = errors +1
    
    errors_train = errors
    
    errors = 0
    for i in range(len(X_test)):
        r = np.dot(w_lda[:, 0], X_test[i])
        label = r < c
        if label != t_test[i]:
            errors = errors +1
    errors_test = errors
    
    return errors_train, errors_test

# Plot c into the histograms
c = calc_threshold(m0, m1, w_lda)
plot_histograms_with_c(c, w_lda, X, t, X_test, t_test)

# Use c to assign class labels and print the classification error
errors_train, errors_test = assign_labels_by_c(c, w_lda, X, X_test, t, t_test)
print("Classification errors on the training set: " + str(errors_train) + " errors on " + str(len(X)) + " elements")
print("Classification errors on the test set: " + str(errors_test) + " errors on " + str(len(X_test)) + " elements")
# Out:
# -2.378379995868631
# Classification errors on the training set: 0 errors on 74 elements
# Classification errors on the test set: 1 errors on 31 elements

# %% [markdown]
# ## Task 3: Logistic Regression
#
# Next, we will consider classification using Logistic Regression. Below, you find all imports that are necessary.

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
import copy

# %% [markdown]
# **Task 3.1: Iterative Reweighted Least Squares**
#
# 1. Implement the IRLS algorithm and output at each iteration the current training error. Remember the weight are updated according to:
# $$ w' = w - ( \Phi^T R \Phi ) ^ {-1} \Phi^T (y - t)$$
# Where $y$ is the prediction, $t$ the ground truth target, $R$ the weighting matrix and $\Phi$ the design matrix.
# 2. Apply the IRLS algorithm on data and compute a test error (see the code below).
# 3. Compare the results of your implementation to the sklearn implementation of `LogisticRegression(penalty='none')`. Do you get the same result?
# 4. Use the `preprocess` function defined earlier to normalize the data.

# %%
# Task 3.1 IRLS

# Generate new set of data
X, X_test, t, t_test = split_data(X_all, t_all, seed=1)

# Import for sigmoid
from scipy.special import expit

# Seed
np.random.seed(1)

# Preprocessing
_X, __t = preprocess(X, t)

_t = np.zeros(__t.shape)
for i in range(len(_t)):
    _t[i] = 1 if __t[i] else -1
_t = _t[:, None]
    
    
# Constants
max_iter = 100
weights = np.random.rand(64,1)

# Initial prediction
y = expit(np.dot(weights.T, _X.T))

# Initial error
mse = 10000

for idx in range(max_iter):
    
    old_mse = mse
    old_w = weights
    
    # Calculate R matrix
    R = np.identity(y.size)
    for n in range(y.size):
        R[n, n] = y[0, n] * (1 - y[0, n])
    
    
    
    # Calculate new weights
    gradE = np.dot(_X.T, (y.T - _t))    
    hessian = np.dot(_X.T, np.dot(R, _X))    
    inv_hessian = np.linalg.inv(hessian)
    
    weights = weights - np.dot(inv_hessian, gradE)
    
    # Alternative way
    #R_inv = np.linalg.inv(R)
    #z = np.dot(_X, weights) - np.dot(R_inv, (y.T - _t))
    #hessian = np.dot(_X.T, np.dot(R, _X))
    #hessian_inv = np.linalg.inv(hessian)
    
    #weights = np.dot(hessian_inv, _X.T).dot(R).dot(z)
    
    
    # Make new predictions
    #print("W:", weights.shape)
    #print("X:", _X.shape)
    y = expit(np.dot(weights.T, _X.T)) 
    
    # Calculate error
    mse = ((y.T - _t)**2).mean(axis=0)
    print("Training error after iteration " + str(idx) + ": " + str(mse))

    # Break if error does not decrease anymore
    if False: #old_mse == mse or old_mse < mse:
        mse = old_mse
        weights = old_w
        break
        
print("Final training set error: " + str(mse))


# Compute error on test set

# Preprocessing
_X_test, __t_test = preprocess(X_test, t_test)

_t_test = np.zeros(__t_test.shape)
for i in range(len(_t_test)):
    _t_test[i] = 1 if __t_test[i] else -1
_t_test = _t_test[:, None]

# Prediction
y = expit(np.dot(weights.T, _X_test.T))

error = ((y.T - _t_test)**2).mean(axis=0)

print("Final test set error: " + str(error))


# Try on Sklearn's logistic regression
_t = _t.flatten()
clf = LogisticRegression(penalty='none').fit(_X, _t)
y = clf.predict(_X_test)

error = ((y - _t_test.flatten())**2).mean(axis=0)

print("SkLearn test set error: " + str(error))
# Out:
# Training error after iteration 0: [1.14812729]
# Training error after iteration 1: [1.40540541]
# Training error after iteration 2: [1.13851351]
# Training error after iteration 3: [1.13851351]
# Training error after iteration 4: [1.13851351]
# Training error after iteration 5: [1.13851351]
# Training error after iteration 6: [1.13851351]
# Training error after iteration 7: [1.13851351]
# Training error after iteration 8: [1.13851351]
# Training error after iteration 9: [1.13851351]
# Training error after iteration 10: [1.13851351]
# Training error after iteration 11: [1.13851351]
# Training error after iteration 12: [1.13851351]
# Training error after iteration 13: [1.13851351]
# Training error after iteration 14: [1.13851351]
# Training error after iteration 15: [1.13851351]
# Training error after iteration 16: [1.13851351]
# Training error after iteration 17: [1.13851351]
# Training error after iteration 18: [1.13851351]
# Training error after iteration 19: [1.13851351]
# Training error after iteration 20: [1.13851351]
# Training error after iteration 21: [1.13851351]
# Training error after iteration 22: [1.13851351]
# Training error after iteration 23: [1.13851351]
# Training error after iteration 24: [1.13851351]
# Training error after iteration 25: [1.13851351]
# Training error after iteration 26: [1.13851351]
# Training error after iteration 27: [1.13851351]
# Training error after iteration 28: [1.13851351]
# Training error after iteration 29: [1.13851351]
# Training error after iteration 30: [1.13851351]
# Training error after iteration 31: [1.13851351]
# Training error after iteration 32: [1.13851351]
# Training error after iteration 33: [1.13851351]
# Training error after iteration 34: [1.13851351]
# Training error after iteration 35: [1.13851351]
# Training error after iteration 36: [1.13851351]
# Training error after iteration 37: [1.13851351]
# Training error after iteration 38: [1.13851351]
# Training error after iteration 39: [1.13851351]
# Training error after iteration 40: [1.13851351]
# Training error after iteration 41: [1.13851351]
# Training error after iteration 42: [1.13851351]
# Training error after iteration 43: [1.13851351]
# Training error after iteration 44: [1.13851351]
# Training error after iteration 45: [1.13851351]
# Training error after iteration 46: [1.13851351]
# Training error after iteration 47: [1.13851351]
# Training error after iteration 48: [1.13851351]
# Training error after iteration 49: [1.13851351]
# Training error after iteration 50: [1.13851351]
# Training error after iteration 51: [1.13851351]
# Training error after iteration 52: [1.13851351]
# Training error after iteration 53: [1.13851351]
# Training error after iteration 54: [1.13851351]
# Training error after iteration 55: [1.13851351]
# Training error after iteration 56: [1.13851351]
# Training error after iteration 57: [1.13851351]
# Training error after iteration 58: [1.13851351]
# Training error after iteration 59: [1.13851351]
# Training error after iteration 60: [1.13851351]
# Training error after iteration 61: [1.13851351]
# Training error after iteration 62: [1.13851351]
# Training error after iteration 63: [1.13851351]
# Training error after iteration 64: [1.13851351]
# Training error after iteration 65: [1.13851351]
# Training error after iteration 66: [1.13851351]
# Training error after iteration 67: [1.13851351]
# Training error after iteration 68: [1.13851351]
# Training error after iteration 69: [1.13851351]
# Training error after iteration 70: [1.13851351]
# Training error after iteration 71: [1.13851351]
# Training error after iteration 72: [1.13851351]
# Training error after iteration 73: [1.13851351]
# Training error after iteration 74: [1.13851351]
# Training error after iteration 75: [1.13851351]
# Training error after iteration 76: [1.13851351]
# Training error after iteration 77: [1.13851351]
# Training error after iteration 78: [1.13851351]
# Training error after iteration 79: [1.13851351]
# Training error after iteration 80: [1.13851351]
# Training error after iteration 81: [1.13851351]
# Training error after iteration 82: [1.13851351]
# Training error after iteration 83: [1.13851351]
# Training error after iteration 84: [1.13851351]
# Training error after iteration 85: [1.13851351]
# Training error after iteration 86: [1.13851351]
# Training error after iteration 87: [1.13851351]
# Training error after iteration 88: [1.13851351]
# Training error after iteration 89: [1.13851351]
# Training error after iteration 90: [1.13851351]
# Training error after iteration 91: [1.13851351]
# Training error after iteration 92: [1.13851351]
# Training error after iteration 93: [1.13851351]
# Training error after iteration 94: [1.13851351]
# Training error after iteration 95: [1.13851351]
# Training error after iteration 96: [1.13851351]
# Training error after iteration 97: [1.13851351]
# Training error after iteration 98: [1.13851351]
# Training error after iteration 99: [1.13851351]
# Final training set error: [1.13851351]
# Final test set error: [1.70967742]
# SkLearn test set error: 0.3870967741935484

# %%
def sig(X):
    return 1/(1+np.exp(-X))

def y(X, w):
    return sig(X.dot(w))

def R(y):
    R = np.identity(y.size)
    R = R*(y*(1-y))
    return R

def irls(X, t):
    X,t = preprocess(X,t)
    w = np.ones(X.shape[1])
    w = w.reshape(w.size, 1)
    t = np.array(list(map(lambda x: 1 if x else -1, t)))
    t = t.reshape(t.size, 1)
    
    for i in range(5):
        y_ = y(X,w)
        w = w - np.linalg.inv(X.T.dot(R(y_)).dot(X)).dot((X.T).dot(y_-t))
        
irls(X, t)
# Out:
# [[ 1.00112690e+15]
#  [-2.40814689e+14]
#  [ 2.20320524e+15]
#  [ 5.56151936e+14]
#  [-2.80705887e+13]
#  [ 5.49722782e+14]
#  [-3.29577931e+15]
#  [ 1.37233170e+13]
#  [ 1.95269722e+15]
#  [ 9.45696669e+12]
#  [-3.41491716e+14]
#  [ 6.56264583e+15]
#  [ 8.55257313e+14]
#  [-2.76027050e+15]
#  [ 2.59227693e+14]
#  [-7.38449422e+14]
#  [ 2.32321753e+14]
#  [-1.27705950e+14]
#  [ 3.61263422e+14]
#  [ 4.33445301e+14]
#  [-2.69125107e+14]
#  [-2.43912633e+14]
#  [ 7.89772461e+13]
#  [-5.19674444e+14]
#  [-5.58785400e+13]
#  [-4.82736712e+14]
#  [-3.67675297e+15]
#  [ 6.52574501e+14]
#  [-1.20439787e+15]
#  [-1.14880643e+15]
#  [-7.26922883e+14]
#  [-1.37813750e+14]
#  [-2.05261086e+14]
#  [-1.28154950e+14]
#  [ 3.43990590e+14]
#  [ 1.22198941e+14]
#  [-1.14421224e+15]
#  [ 1.80864625e+15]
#  [-2.67045671e+14]
#  [-1.51213062e+15]
#  [ 3.57853615e+15]
#  [-2.06007822e+15]
#  [ 3.24594502e+14]
#  [ 4.10324240e+15]
#  [-4.55530097e+14]
#  [ 3.08642198e+15]
#  [-8.44336394e+13]
#  [ 6.93296640e+14]
#  [ 7.84762091e+14]
#  [ 1.58054169e+14]
#  [ 1.00927873e+14]
#  [-2.93525705e+15]
#  [ 1.15624584e+15]
#  [-6.58735253e+15]
#  [ 3.70184765e+15]
#  [-1.53085905e+15]
#  [-5.80514814e+14]
#  [-5.17685945e+15]
#  [-1.70012178e+15]
#  [ 3.57131612e+15]
#  [ 1.41360830e+15]
#  [-1.10452358e+15]
#  [-9.18165542e+13]
#  [-1.22289009e+14]]
# [[-3.80747605e+23]
#  [-2.05883030e+23]
#  [-2.89298559e+24]
#  [-1.06263614e+24]
#  [ 2.12520497e+23]
#  [ 3.40240009e+23]
#  [-2.64397149e+23]
#  [-3.17262347e+22]
#  [ 1.74295705e+23]
#  [ 8.93748092e+23]
#  [-2.22702184e+23]
#  [-7.59038934e+23]
#  [ 8.45623872e+24]
#  [ 1.09191447e+22]
#  [-2.45616034e+24]
#  [ 1.62655848e+24]
#  [ 7.06247414e+24]
#  [-3.57912233e+22]
#  [ 1.07673462e+24]
#  [-9.19582573e+22]
#  [-1.23177631e+24]
#  [-1.50956765e+24]
#  [ 1.83323137e+24]
#  [-2.01092983e+23]
#  [ 7.85507676e+21]
#  [ 4.09451911e+23]
#  [-7.92104789e+23]
#  [ 3.44261868e+23]
#  [ 1.63779667e+20]
#  [ 3.30450467e+23]
#  [ 1.21317722e+23]
#  [ 2.30747817e+23]
#  [-6.58735369e+23]
#  [-4.14001163e+22]
#  [-1.87852294e+23]
#  [-1.02548008e+23]
#  [ 2.88109559e+23]
#  [ 6.90073653e+23]
#  [ 1.48652171e+23]
#  [-6.97631797e+23]
#  [ 5.09672417e+24]
#  [ 4.76068006e+23]
#  [ 3.19604953e+23]
#  [ 8.86496879e+23]
#  [ 2.45291492e+23]
#  [ 1.38098055e+24]
#  [-3.03945928e+23]
#  [ 6.70900691e+22]
#  [-2.10571251e+23]
#  [ 6.32993046e+22]
#  [ 9.53874748e+22]
#  [ 5.57416426e+23]
#  [ 1.92175492e+24]
#  [-4.06726393e+24]
#  [ 1.88828430e+24]
#  [-5.97592677e+24]
#  [-5.64484539e+23]
#  [-5.73167582e+24]
#  [-1.14492066e+23]
#  [-3.35099183e+23]
#  [ 1.51223991e+23]
#  [-3.23087892e+24]
#  [-1.13979016e+23]
#  [ 3.25555309e+23]]
# E:\data\program\anaconda\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-201-9abd3068dbfa> in <module>
#      22         print(w)
#      23
# ---> 24 irls(X, t)
#
# <ipython-input-201-9abd3068dbfa> in irls(X, t)
#      19     for i in range(5):
#      20         y_ = y(X,w)
# ---> 21         w = w - np.linalg.inv(X.T.dot(R(y_)).dot(X)).dot((X.T).dot(y_-t))
#      22         print(w)
#      23
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# E:\data\program\anaconda\lib\site-packages\numpy\linalg\linalg.py in inv(a)
#     545     signature = 'D->D' if isComplexType(t) else 'd->d'
#     546     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 547     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     548     return wrap(ainv.astype(result_t, copy=False))
#     549
#
# E:\data\program\anaconda\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_singular(err, flag)
#      95
#      96 def _raise_linalgerror_singular(err, flag):
# ---> 97     raise LinAlgError("Singular matrix")
#      98
#      99 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %% [markdown]
# **Task 3.2: Logistic Regression with Regularization**
#
# 1. Set sklearn's penalty parameter to `l1` and `l2`. Use the range `np.linspace(0.02, 1, 25)` for the parameter `C`, which controls the strength of regularization.
# 2. Plot strength of regularization over accuracy. Does regularization improve the scores?
# 3. Visualize the coefficients of the regularized settings and the unregularized setting. What do you observe?
# 3. Compare the coefficients to the LDA weights.

# %%
from matplotlib import pyplot as plt

c = np.linspace(0.02, 1, 25)

# New dataset
X, X_test, t, t_test = split_data(X_all, t_all, seed=1)

# Preprocessing
_X, __t = preprocess(X, t)

_t = np.zeros(__t.shape)
for i in range(len(_t)):
    _t[i] = 1 if __t[i] else -1
_t = _t[:, None]


_X_test, __t_test = preprocess(X_test, t_test)

_t_test = np.zeros(__t_test.shape)
for i in range(len(_t_test)):
    _t_test[i] = 1 if __t_test[i] else -1
_t_test = _t_test[:, None]

# L1 regularization
_t = _t.flatten()
clf = LogisticRegression(penalty='l2', C=c).fit(_X, _t)
y = clf.predict(_X_test)

error = ((y - _t_test.flatten())**2).mean(axis=0)

print("SkLearn test set error: " + str(error))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-295-487e6819b65b> in <module>
#      24 # L1 regularization
#      25 _t = _t.flatten()
# ---> 26 clf = LogisticRegression(penalty='l2', C=c).fit(_X, _t)
#      27 y = clf.predict(_X_test)
#      28
#
# E:\data\program\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1490         if not isinstance(self.C, numbers.Number) or self.C < 0:
#    1491             raise ValueError("Penalty term must be positive; got (C=%r)"
# -> 1492                              % self.C)
#    1493         if self.penalty == 'elasticnet':
#    1494             if (not isinstance(self.l1_ratio, numbers.Number) or
#
# ValueError: Penalty term must be positive; got (C=array([0.02      , 0.06083333, 0.10166667, 0.1425    , 0.18333333,
#        0.22416667, 0.265     , 0.30583333, 0.34666667, 0.3875    ,
#        0.42833333, 0.46916667, 0.51      , 0.55083333, 0.59166667,
#        0.6325    , 0.67333333, 0.71416667, 0.755     , 0.79583333,
#        0.83666667, 0.8775    , 0.91833333, 0.95916667, 1.        ]))

# %% [markdown]
# ### Task 3.3: Arryhtymia and Ionosphere Dataset
#
# Next, let's run your code on the datasets from openml below.
#
# 1. First, explore the dataset. Which differences to ionosphere do you encounter?
# 2. Run your IRLS implementation on unprocessed data and preprocessed data. Does it work? If not, why?
# 3. Compare with sklearn Logistic Regression.

# %%
from sklearn.datasets import fetch_openml
X_arr, t_arr = fetch_openml('arrhythmia', version=1, return_X_y=True)
X_arr = np.nan_to_num(X_arr)[:, :25]
t_arr = np.array([1 if l == '1' else 0 for l in t_arr])

X_ion, t_ion = fetch_openml('ionosphere', version=1, return_X_y=True)
t_ion = np.array([1 if l == 'g' else 0 for l in t_ion])
